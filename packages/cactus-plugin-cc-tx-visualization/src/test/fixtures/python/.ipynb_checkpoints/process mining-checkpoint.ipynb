# %%
import os
path = os.getcwd()
parent = os.path.dirname(path)


# Change path if necessary
file_path = parent + "/../csv/use-case-besu-fabric-6-events.csv"
file_path_other_model = parent + "/../csv/dummy-use-case-invalid.csv"

import sys

if __name__ == '__main__':
    print(sys.argv)
    print(file_path)



# import sys

# accept command line arguments
# inputArg1 = sys.argv[1]

#print('inputArg1: ',inputArg1)
# Out:
# ['/usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py', '-f', '/home/bruno/.local/share/jupyter/runtime/kernel-63d8772c-ba30-4890-a468-f39af6d95407.json']
# /home/bruno/Documentos/blockchain-integration-framework/packages/cactus-plugin-cc-tx-visualization/src/test/fixtures/../csv/use-case-besu-fabric-6-events.csv

# %%
# uncomment if problems with dependencies
#%pip install pm4py
#%pip install pandas
import pm4py
import datetime as dt
import time
import pandas

# process mining
from pm4py.algo.discovery.alpha import algorithm as alpha_miner
from pm4py.algo.discovery.inductive import algorithm as inductive_miner
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery

# viz
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.visualization.process_tree import visualizer as pt_visualizer
from pm4py.visualization.heuristics_net import visualizer as hn_visualizer
from pm4py.visualization.dfg import visualizer as dfg_visualization

from pm4py.objects.conversion.process_tree import converter as pt_converter

# %%
def import_csv_original(file_path):
    event_log = pandas.read_csv(file_path, sep=';')
    event_log = pm4py.format_dataframe(event_log, case_id='caseID', activity_key='methodName', timestamp_key='timestamp')
    return event_log

def getStartActivities(event_log):
    s = pm4py.get_start_activities(event_log)
    print("Start activities: {}\n".format(s))
    return s
def getEndActivities(event_log):
    e = pm4py.get_end_activities(event_log)
    print("End activities: {}\n".format(e))
    return (e)

def getAttributeFromLog(event_log, attr):
    entries = pm4py.get_event_attribute_values(event_log,attr)
    print("Entries: {}\n".format(entries))
    return entries

# %%
print(file_path)
log = import_csv_original(file_path)
log_other_model = import_csv_original(file_path_other_model)
print(log)
print("lenght is", len(log))
print(log_other_model)
print("lenght is", len(log_other_model))
startAct = getStartActivities(log)
endAct = getEndActivities(log)
timestamps = getAttributeFromLog(log, "timestamp")
# Out:
# /home/bruno/Documentos/blockchain-integration-framework/packages/cactus-plugin-cc-tx-visualization/src/test/fixtures/../csv/use-case-besu-fabric-6-events.csv
#         caseID                                          receiptID  \
# 0  FABRIC_BESU  0xd184f5a49d170e2f7f9fcb7996e8db3d7764c13d798f...
# 1  FABRIC_BESU  0xc315d4ee310a04d4c0949279f4edba34fa8fb35cf5fe...
# 2  FABRIC_BESU  bb8195efc40b97ab3e892bb7547b8071c15cfb61e964d7...
# 3  FABRIC_BESU  8d64b9d423cdae3a07c1ec2dbd8277ec81859779f6a3b1...
# 4  FABRIC_BESU  ae0551a9c76c085c19516909685b1e9103ed7cea2bcd94...
# 5  FABRIC_BESU  6fb229c25ce27b86919afc329d4050edcd0215a7b55daa...
#
#                          timestamp blockchainID  \
# 0 2024-04-15 09:04:35.256000+00:00      BESU_2X
# 1 2024-04-15 09:04:36.120000+00:00      BESU_2X
# 2 2024-04-15 09:04:39.263000+00:00     FABRIC_2
# 3 2024-04-15 09:04:42.123000+00:00     FABRIC_2
# 4 2024-04-15 09:04:44.900000+00:00     FABRIC_2
# 5 2024-04-15 09:04:47.812000+00:00     FABRIC_2
#
#                       invocationType     methodName  \
# 0                               SEND    createAsset
# 1                               SEND      lockAsset
# 2  FabricContractInvocationType.SEND    CreateAsset
# 3  FabricContractInvocationType.SEND  TransferAsset
# 4  FabricContractInvocationType.SEND  TransferAsset
# 5  FabricContractInvocationType.SEND    DeleteAsset
#
#                      parameters                                    identity  \
# 0                  ["asset1",5]  0x627306090abab3a6e1400e9345bc60c78a8bef57
# 1                    ["asset1"]  0x627306090abab3a6e1400e9345bc60c78a8bef57
# 2  ["asset1","19","fabricUser"]                                       user2
# 3           ["asset1","owner2"]                                       user2
# 4           ["asset1","owner1"]                                       user2
# 5                    ["asset1"]                                       user2
#
#    cost  carbonFootprint  latency  revenue case:concept:name   concept:name  \
# 0  6.84          0.00018    12586        0       FABRIC_BESU    createAsset
# 1  2.18          0.00018    11722        0       FABRIC_BESU      lockAsset
# 2  0.00          0.00018     8580        0       FABRIC_BESU    CreateAsset
# 3  0.00          0.00018     5733        0       FABRIC_BESU  TransferAsset
# 4  0.00          0.00018     2956        0       FABRIC_BESU  TransferAsset
# 5  0.00          0.00018       45        0       FABRIC_BESU    DeleteAsset
#
#                     time:timestamp  @@index  @@case_index
# 0 2024-04-15 09:04:35.256000+00:00        0             0
# 1 2024-04-15 09:04:36.120000+00:00        1             0
# 2 2024-04-15 09:04:39.263000+00:00        2             0
# 3 2024-04-15 09:04:42.123000+00:00        3             0
# 4 2024-04-15 09:04:44.900000+00:00        4             0
# 5 2024-04-15 09:04:47.812000+00:00        5             0
# lenght is 6
#                    caseID receiptID                        timestamp  \
# 0   INVALID_FABRIC_BESU_1   txID1_1 2024-04-15 09:09:47.142000+00:00
# 1   INVALID_FABRIC_BESU_1   txID3_1 2024-04-15 09:09:47.144000+00:00
# 2   INVALID_FABRIC_BESU_1   txID2_1 2024-04-15 09:09:47.145000+00:00
# 3   INVALID_FABRIC_BESU_1   txID4_1 2024-04-15 09:09:47.146000+00:00
# 4   INVALID_FABRIC_BESU_1   txID5_1 2024-04-15 09:09:47.147000+00:00
# 5   INVALID_FABRIC_BESU_1   txID6_1 2024-04-15 09:09:47.148000+00:00
# 6   INVALID_FABRIC_BESU_2   txID1_2 2024-04-15 09:09:47.142000+00:00
# 7   INVALID_FABRIC_BESU_2   txID3_2 2024-04-15 09:09:47.144000+00:00
# 8   INVALID_FABRIC_BESU_2   txID2_2 2024-04-15 09:09:47.145000+00:00
# 9   INVALID_FABRIC_BESU_2   txID4_2 2024-04-15 09:09:47.146000+00:00
# 10  INVALID_FABRIC_BESU_2   txID5_2 2024-04-15 09:09:47.147000+00:00
# 11  INVALID_FABRIC_BESU_2   txID6_2 2024-04-15 09:09:47.148000+00:00
#
#    blockchainID                     invocationType       methodName  \
# 0      FABRIC_2  FabricContractInvocationType.SEND  InitializeAsset
# 1      FABRIC_2  FabricContractInvocationType.SEND      CreateAsset
# 2      FABRIC_2  FabricContractInvocationType.SEND        LockAsset
# 3      FABRIC_2  FabricContractInvocationType.SEND    TransferAsset
# 4      FABRIC_2  FabricContractInvocationType.SEND    TransferAsset
# 5      FABRIC_2  FabricContractInvocationType.SEND      DeleteAsset
# 6      FABRIC_2  FabricContractInvocationType.SEND  InitializeAsset
# 7      FABRIC_2  FabricContractInvocationType.SEND      CreateAsset
# 8      FABRIC_2  FabricContractInvocationType.SEND        LockAsset
# 9      FABRIC_2  FabricContractInvocationType.SEND    TransferAsset
# 10     FABRIC_2  FabricContractInvocationType.SEND    TransferAsset
# 11     FABRIC_2  FabricContractInvocationType.SEND      DeleteAsset
#
#                      parameters identity  cost  carbonFootprint  latency  \
# 0              ["asset1","100"]        A     0          0.00018       52
# 1              ["asset1","100"]        A     0          0.00018       53
# 2                    ["asset1"]        A     0          0.00018       54
# 3    ["asset1","targetAccount"]        A     0          0.00018       54
# 4   ["asset1","targetAccount2"]        A     0          0.00018       55
# 5                    ["asset1"]        A     0          0.00018       57
# 6              ["asset1","100"]        A     0          0.00018       65
# 7              ["asset1","100"]        A     0          0.00018       65
# 8                    ["asset1"]        A     0          0.00018       65
# 9    ["asset1","targetAccount"]        A     0          0.00018       67
# 10  ["asset1","targetAccount2"]        A     0          0.00018       68
# 11                   ["asset1"]        A     0          0.00018       69
#
#     revenue      case:concept:name     concept:name  \
# 0         0  INVALID_FABRIC_BESU_1  InitializeAsset
# 1         0  INVALID_FABRIC_BESU_1      CreateAsset
# 2         0  INVALID_FABRIC_BESU_1        LockAsset
# 3         0  INVALID_FABRIC_BESU_1    TransferAsset
# 4         0  INVALID_FABRIC_BESU_1    TransferAsset
# 5         0  INVALID_FABRIC_BESU_1      DeleteAsset
# 6         0  INVALID_FABRIC_BESU_2  InitializeAsset
# 7         0  INVALID_FABRIC_BESU_2      CreateAsset
# 8         0  INVALID_FABRIC_BESU_2        LockAsset
# 9         0  INVALID_FABRIC_BESU_2    TransferAsset
# 10        0  INVALID_FABRIC_BESU_2    TransferAsset
# 11        0  INVALID_FABRIC_BESU_2      DeleteAsset
#
#                      time:timestamp  @@index  @@case_index
# 0  2024-04-15 09:09:47.142000+00:00        0             0
# 1  2024-04-15 09:09:47.144000+00:00        1             0
# 2  2024-04-15 09:09:47.145000+00:00        2             0
# 3  2024-04-15 09:09:47.146000+00:00        3             0
# 4  2024-04-15 09:09:47.147000+00:00        4             0
# 5  2024-04-15 09:09:47.148000+00:00        5             0
# 6  2024-04-15 09:09:47.142000+00:00        6             1
# 7  2024-04-15 09:09:47.144000+00:00        7             1
# 8  2024-04-15 09:09:47.145000+00:00        8             1
# 9  2024-04-15 09:09:47.146000+00:00        9             1
# 10 2024-04-15 09:09:47.147000+00:00       10             1
# 11 2024-04-15 09:09:47.148000+00:00       11             1
# lenght is 12
# Start activities: {'createAsset': 1}
#
# End activities: {'DeleteAsset': 1}
#
# Entries: {Timestamp('2024-04-15 09:04:35.256000+0000', tz='UTC'): 1, Timestamp('2024-04-15 09:04:36.120000+0000', tz='UTC'): 1, Timestamp('2024-04-15 09:04:39.263000+0000', tz='UTC'): 1, Timestamp('2024-04-15 09:04:42.123000+0000', tz='UTC'): 1, Timestamp('2024-04-15 09:04:44.900000+0000', tz='UTC'): 1, Timestamp('2024-04-15 09:04:47.812000+0000', tz='UTC'): 1}

# %% [markdown]
# ### Install graphviz, if not done already
# Open a terminal window and intall graphviz with:
# `sudo apt install graphviz`

# %%
#Another way to discover the tree
# # create the process tree
#tree = inductive_miner.apply_tree(log)

# viz
#gviz = pt_visualizer.apply(tree)
#pt_visualizer.view(gviz)# convert the process tree to a petri net

start_time = time.perf_counter()
process_tree = pm4py.discover_process_tree_inductive(log)
print(process_tree)
end_time = time.perf_counter()
pm4py.view_process_tree(process_tree)
print("after view_process_tree")

start_time_2 = time.perf_counter()
bpmn_model = pm4py.convert_to_bpmn(process_tree)
end_time_2 = time.perf_counter()
print(f"Execution Time : {end_time_2 - start_time_2:0.3f}" )
timeDiff_2 = end_time_2 - start_time_2
print(f"Execution Time (ms): {timeDiff_2*1000:0.3f}" )

pm4py.view_bpmn(bpmn_model)

print(f"Start Time : {start_time}")
print(f"End Time : {end_time}")
timeDiff_3 = end_time - start_time
print(f"Execution Time : {timeDiff_3:0.3f}")
print(f"Execution Time (ms): {timeDiff_3*1000:0.3f}" )


#net, initial_marking, final_marking = pt_converter.apply(tree)

# alternatively, use the inductive_miner to create a petri net from scratch
# net, initial_marking, final_marking = inductive_miner.apply(log)

# viz
parameters = {pn_visualizer.Variants.FREQUENCY.value.Parameters.FORMAT: "png"}
# Out:
# ->( 'createAsset', 'lockAsset', 'CreateAsset', *( 'TransferAsset', tau ), 'DeleteAsset' )

# %%
dfg, start_activities, end_activities = pm4py.discover_dfg(log)
pm4py.view_dfg(dfg, start_activities, end_activities)

map = pm4py.discover_heuristics_net(log)
print(map)
pm4py.view_heuristics_net(map)
# Out:
# {'CreateAsset': (node:CreateAsset connections:{TransferAsset:[0.5]}), 'TransferAsset': (node:TransferAsset connections:{DeleteAsset:[0.5], TransferAsset:[0.5]}), 'DeleteAsset': (node:DeleteAsset connections:{}), 'createAsset': (node:createAsset connections:{lockAsset:[0.5]}), 'lockAsset': (node:lockAsset connections:{CreateAsset:[0.5]})}

# %%
# heuristics miner
net, im, fm = heuristics_miner.apply(log)

# viz
gviz = pn_visualizer.apply(net, im, fm)
pn_visualizer.view(gviz)
